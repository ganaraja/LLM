# %% [markdown]
# <center>
# <img src="https://supportvectors.ai/logo-poster-transparent.png" width="400px" style="opacity:0.7">
# </center>
#
# # Frequently used libraries
#
# | Name of the Tool | URL (Official GitHub) | One-Liner on the Purpose | GitHub Stars |
# |------------------|------------------------|---------------------------|---------------|
# | Qdrant | [GitHub](https://github.com/qdrant/qdrant) | High-performance, scalable vector database and search engine for AI | 24k |
# | FAISS | [GitHub](https://github.com/facebookresearch/faiss) | Library for efficient similarity search and clustering of dense vector embeddings | 35.3k |
# | Sentence-Transformers | [GitHub](https://github.com/UKPLab/sentence-transformers) | Framework for computing text embeddings and semantic similarity tasks | 16.8k |
# | Transformers | [GitHub](https://github.com/huggingface/transformers) | Library of pretrained models for NLP, vision, audio; supports fine-tuning and inference | 145k |
# | PyTorch | [GitHub](https://github.com/pytorch/pytorch) | Dynamic neural networks and tensors with GPU acceleration | 90.6k |
# | Torchvision | [GitHub](https://github.com/pytorch/vision) | Computer vision library with popular datasets, model architectures, and image transformations | 16.9k |
# | Pandas | [GitHub](https://github.com/pandas-dev/pandas) | Data analysis and manipulation library providing DataFrame structures | 45.6k |
# | NumPy | [GitHub](https://github.com/numpy/numpy) | Fundamental package for numerical computing in Python | 29.6k |
# | Matplotlib | [GitHub](https://github.com/matplotlib/matplotlib) | Library for creating static, animated, and interactive visualizations | 21.3k |
# | scikit-learn | [GitHub](https://github.com/scikit-learn/scikit-learn) | ML library for classification, regression, and clustering built on NumPy/SciPy | 62.2k |
# | SciPy | [GitHub](https://github.com/scipy/scipy) | Scientific computing with optimization, integration, and linear algebra tools | 13.7k |
# | rank-bm25 | [GitHub](https://github.com/dorianbrown/rank_bm25) | Python implementation of BM25 algorithms for document ranking | 1.2k |
# | Ray | [GitHub](https://github.com/ray-project/ray) | Distributed framework for scaling AI and Python applications | 37.4k |
# | PEFT | [GitHub](https://github.com/huggingface/peft) | Parameter-Efficient Fine-Tuning for LLMs (e.g., LoRA) | 18.7k |
# | Unsloth | [GitHub](https://github.com/unslothai/unsloth) | Efficient LLM fine-tuning with faster training and lower memory usage | 40k |
# | Segment Anything (SAM) | [GitHub](https://github.com/facebookresearch/segment-anything) | Produces high-quality object masks from prompts | 50.3k |
# | CLIP | [GitHub](https://github.com/openai/CLIP) | Aligns images and text using contrastive language-image pretraining for zero-shot classification | 29.3k |
# | BLIP | [GitHub](https://github.com/salesforce/BLIP) | Unified vision-language understanding and generation (e.g. captioning, retrieval) | 5.3k |
# | LLaVA | [GitHub](https://github.com/haotian-liu/LLaVA) | Visual instruction tuning framework combining vision and LLMs | 22.7k |
# | Nougat | [GitHub](https://github.com/facebookresearch/nougat) | OCR model for parsing academic documents with neural networks | 9.5k |
# | OpenAI Gym | [GitHub](https://github.com/openai/gym) | Toolkit for building and comparing reinforcement learning algorithms | 36k |
# | Streamlit | [GitHub](https://github.com/streamlit/streamlit) | Build and share interactive data applications easily | 39.7k |
# | Chainlit | [GitHub](https://github.com/Chainlit/chainlit) | Rapidly build and deploy conversational AI apps in Python | 9.8k |
# | Vanna | [GitHub](https://github.com/vanna-ai/vanna) | Chat with your SQL database 📊. Accurate Text-to-SQL Generation via LLMs using RAG | 18k |
# | Donut | [GitHub](https://github.com/clovaai/donut) | OCR-free Document Understanding Transformer | 6.3k |
# | ColBERT | [GitHub](https://github.com/stanford-futuredata/ColBERT) | State-of-the-art neural search (contextual late interaction) | 3.4k |
# | Colpali | [GitHub](https://github.com/illuin-tech/colpali) | The code used to train and run inference with the ColVision models, e.g. ColPali, ColQwen2, and ColSmol. | 1.9k |
# | Docling | [GitHub](https://github.com/docling-project/docling) | Get your documents ready for gen AI | 31.3k |
# | Semchunk | [GitHub](https://github.com/isaacus-dev/semchunk) | Fast, lightweight and easy-to-use Python library for splitting text into semantically meaningful chunks. | 316 |
# | Unstructured | [GitHub](https://github.com/Unstructured-IO/unstructured) | Preprocessing pipelines for ML (text, HTML, PDF, etc.) | 11.4k |
# | LangChain | [GitHub](https://github.com/langchain-ai/langchain) | Framework for building LLM-powered chains and agents | 109k |
# | LlamaIndex | [GitHub](https://github.com/run-llama/llama_index) | Data framework & connectors to augment LLMs with external data | 42.1k |
# | TRL | [GitHub](https://github.com/huggingface/trl) | Transformer Reinforcement Learning toolkit | 14.1k |
# | hnswlib | [GitHub](https://github.com/nmslib/hnswlib) | Fast approximate nearest neighbor search using HNSW. | 4.7k |
# | Annoy | [GitHub](https://github.com/spotify/annoy) | Approximate Nearest Neighbors library optimized for memory and disk. | 13.8k |
# | Weaviate | [GitHub](https://github.com/semi-technologies/weaviate) | Vector search engine with built-in ML pipelines and REST API. | 13.6k |
# | Milvus | [GitHub](https://github.com/milvus-io/milvus) | Sub‑second vector similarity search for billion‑scale data. | 35.2k |
# | PaddleOCR | [GitHub](https://github.com/PaddlePaddle/PaddleOCR) | Multilingual OCR system by PaddlePaddle. | 50.1k |
# | Tesseract | [GitHub](https://github.com/tesseract-ocr/tesseract) | Google’s OCR engine for printed text recognition. | 67.3k |
# | EasyOCR | [GitHub](https://github.com/JaidedAI/EasyOCR) | Ready‑to‑use OCR in 80+ languages using PyTorch. | 26.8k |
# | MMOCR | [GitHub](https://github.com/open-mmlab/mmocr) | Toolkit for text detection and recognition using PyTorch. | 8.6k |
# | Apache Spark | [GitHub](https://github.com/apache/spark) | Engine for large-scale data processing and analytics. | 41.2k |
# | SQL Coder | [GitHub](https://github.com/defog-ai/sqlcoder) | AI assistant to generate SQL from natural language. | 3.8k |
# | Data Herald | [GitHub](https://github.com/Dataherald/dataherald) | Tool for scanning and validating tabular datasets. | 3.5k |
# | Fast SAM | [GitHub](https://github.com/CASIA-IVA-Lab/FastSAM) | Efficient image segmentation using Segment Anything Model. | 7.9k |
# | Grounded Segment Anything | [GitHub](https://github.com/IDEA-Research/Grounded-Segment-Anything) | Region-aware image segmentation extension of SAM. | 16.4k |
# | LLaVA-Med | [GitHub](https://github.com/microsoft/LLaVA-Med) | Multimodal LLM for medical visual question answering. | 1.9k |
# | Awesome-LLM-RAG | [GitHub](https://github.com/Shubhamsaboo/awesome-llm-apps) | Curated list of RAG resources. | 33.3k |
# | ragas | [GitHub](https://github.com/explodinggradients/ragas) | RAG pipeline framework by Jina AI. | 9.4k |
# | CrewAI | [GitHub](https://github.com/crewAIInc/crewAI) | Framework for orchestrating role-playing, autonomous AI agents promoting collaborative intelligence | 32.5k |
# | LangGraph | [GitHub](https://github.com/langchain-ai/langgraph) | Low-level orchestration for long-running, stateful AI agents as graphs | 13.6k |
